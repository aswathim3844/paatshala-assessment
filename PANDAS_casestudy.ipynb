# %% [markdown]
# <a href="https://colab.research.google.com/github/aswathim3844/paatshala-assessment/blob/main/PANDAS_casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Import pandas, numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2) Load dataset using pd.read_csv()

# %%
import pandas as pd

url='https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/master/IMDB-Movie-Data.csv'
df=pd.read_csv(url)

# %% [markdown]
# 3) Display: shape, head, column names, datatypes, missing value

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# 4) Check and remove duplicates

# %%
df.drop_duplicates()
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# 5) Rename columns ("Title" > "Movie_Title")

# %%
df.rename(columns={"Title":"Movie_Title"})
# Out:
#      Rank              Movie_Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# 6) Get unique genres

# %%
df['Genre_List'] = df['Genre'].str.split(',')
all_genres = df.explode('Genre_List')
unique_genres = all_genres['Genre_List'].unique()
print(unique_genres)
# Out:
# ['Action' 'Adventure' 'Sci-Fi' 'Mystery' 'Horror' 'Thriller' 'Animation'
#  'Comedy' 'Family' 'Fantasy' 'Drama' 'Music' 'Biography' 'Romance'
#  'History' 'Crime' 'Western' 'War' 'Musical' 'Sport']

# %% [markdown]
# 7) Extract number of genres per movie

# %%
df['Number_of_Genres'] = df['Genre'].str.count(",")+1
display(df[['Title', 'Genre', 'Number_of_Genres']])
# Out:
#                        Title                     Genre  Number_of_Genres
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi                 3
# 1                 Prometheus  Adventure,Mystery,Sci-Fi                 3
# 2                      Split           Horror,Thriller                 2
# 3                       Sing   Animation,Comedy,Family                 3
# 4              Suicide Squad  Action,Adventure,Fantasy                 3
# ..                       ...                       ...               ...
# 995     Secret in Their Eyes       Crime,Drama,Mystery                 3
# 996          Hostel: Part II                    Horror                 1
# 997   Step Up 2: The Streets       Drama,Music,Romance                 3
# 998             Search Party          Adventure,Comedy                 2
# 999               Nine Lives     Comedy,Family,Fantasy                 3
#
# [1000 rows x 3 columns]

# %% [markdown]
# 8) Handle missing values in 'Revenue (Millions)' and 'Metascore

# %%
display(df[['Revenue (Millions)', 'Metascore']].isna().sum())
# Out:
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
display(df[['Revenue (Millions)', 'Metascore']].fillna(0))
# Out:
#      Revenue (Millions)  Metascore
# 0                333.13       76.0
# 1                126.46       65.0
# 2                138.12       62.0
# 3                270.32       59.0
# 4                325.02       40.0
# ..                  ...        ...
# 995                0.00       45.0
# 996               17.54       46.0
# 997               58.01       50.0
# 998                0.00       22.0
# 999               19.64       11.0
#
# [1000 rows x 2 columns]

# %% [markdown]
# 9) Top 5 movies by Rating

# %%
df.sort_values(by=['Rating'],ascending=False).head(5)
# Out:
#      Rank             Title                    Genre  \
# 54     55   The Dark Knight       Action,Crime,Drama
# 80     81         Inception  Action,Adventure,Sci-Fi
# 117   118            Dangal   Action,Biography,Drama
# 36     37      Interstellar   Adventure,Drama,Sci-Fi
# 249   250  The Intouchables   Biography,Comedy,Drama
#
#                                            Description           Director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 117  Former wrestler Mahavir Singh Phogat and his t...      Nitesh Tiwari
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 249  After he becomes a quadriplegic from a paragli...    Olivier Nakache
#
#                                                 Actors  Year  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# ...

# %% [markdown]
# 10) Movies with highest/lowest revenue

# %%
lowest=df.sort_values(by=["Revenue (Millions)"]).head()
lowest
# Out:
#      Rank             Title                  Genre  \
# 231   232  A Kind of Murder   Crime,Drama,Thriller
# 961   962   Into the Forest  Drama,Sci-Fi,Thriller
# 321   322          Lovesong                  Drama
# 68     69         Wakefield                  Drama
# 677   678       Love, Rosie         Comedy,Romance
#
#                                            Description          Director  \
# 231  In 1960s New York, Walter Stackhouse is a succ...      Andy Goddard
# 961  After a massive power outage, two sisters lear...   Patricia Rozema
# 321  The relationship between two friends deepens d...       So Yong Kim
# 68   A man's nervous breakdown causes him to leave ...     Robin Swicord
# 677  Rosie and Alex have been best friends since th...  Christian Ditter
#
#                                                 Actors  Year  \
# 231  Patrick Wilson, Jessica Biel, Haley Bennett, V...  2016
# 961  Ellen Page, Evan Rachel Wood, Max Minghella,Ca...  2015
# ...

# %%
highest=df.sort_values(by=["Revenue (Millions)"],ascending=False).head()
highest
# Out:
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
# 87    88                                      Avatar
# 85    86                              Jurassic World
# 76    77                                The Avengers
# 54    55                             The Dark Knight
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
# 87  Action,Adventure,Fantasy
# 85   Action,Adventure,Sci-Fi
# 76             Action,Sci-Fi
# 54        Action,Crime,Drama
#
#                                           Description           Director  \
# 50  Three decades after the defeat of the Galactic...        J.J. Abrams
# 87  A paraplegic marine dispatched to the moon Pan...      James Cameron
# 85  A new theme park, built on the original site o...    Colin Trevorrow
# 76  Earth's mightiest heroes must come together an...        Joss Whedon
# 54  When the menace known as the Joker wreaks havo...  Christopher Nolan
#
# ...

# %% [markdown]
# 11) Avg. rating by Director

# %%
avg_rating_by_director = df.groupby("Director")["Rating"].mean()
print(avg_rating_by_director)
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
#                        ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 644, dtype: float64

# %% [markdown]
# 12) Movies per year

# %%
df.groupby("Year")["Title"].count()
# Out:
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# Name: Title, dtype: int64

# %% [markdown]
# 13) Movies with rating > 8 & revenue > 100M

# %%
filtered_movies=df[(df['Rating']> 8 ) & (df['Revenue (Millions)']> 100) ]
filtered_movies
# Out:
#      Rank                                         Title  \
# 0       1                       Guardians of the Galaxy
# 6       7                                    La La Land
# 36     37                                  Interstellar
# 50     51    Star Wars: Episode VII - The Force Awakens
# 54     55                               The Dark Knight
# 67     68                            Mad Max: Fury Road
# 74     75                                      Zootopia
# 76     77                                  The Avengers
# 77     78                          Inglourious Basterds
# 80     81                                     Inception
# 82     83                       The Wolf of Wall Street
# 83     84                                     Gone Girl
# 92     93                                      The Help
# 99    100                                  The Departed
# 114   115  Harry Potter and the Deathly Hallows: Part 2
# 124   125                         The Dark Knight Rises
# ...

# %% [markdown]
# 14) Group by Director: avg Rating, Revenue

# %%
df.groupby(['Director'])[['Rating','Revenue (Millions)']].mean()
# Out:
#                      Rating  Revenue (Millions)
# Director
# Aamir Khan             8.50               1.200
# Abdellatif Kechiche    7.80               2.200
# Adam Leon              6.50                 NaN
# Adam McKay             7.00             109.535
# Adam Shankman          6.30              78.665
# ...                     ...                 ...
# Xavier Dolan           7.55               3.490
# Yimou Zhang            6.10              45.130
# Yorgos Lanthimos       7.20               4.405
# Zack Snyder            7.04             195.148
# Zackary Adler          5.10               6.530
#
# [644 rows x 2 columns]

# %% [markdown]
# 15) Group by Year: count, avg Rating

# %%
df.groupby(["Year"])["Rating"].count()
# Out:
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# Name: Rating, dtype: int64

# %%
df.groupby(["Year"])["Rating"].mean()
# Out:
# Year
# 2006    7.125000
# 2007    7.133962
# 2008    6.784615
# 2009    6.960784
# 2010    6.826667
# 2011    6.838095
# 2012    6.925000
# 2013    6.812088
# 2014    6.837755
# 2015    6.602362
# 2016    6.436700
# Name: Rating, dtype: float64

# %% [markdown]
# 16) Create a new column Profitability:
# a) Revenue divided by Duration
# b) Find top 10 most profitable movies

# %%
df['Profitability']=df['Revenue (Millions)']/df['Runtime (Minutes)']
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.sort_values(["Profitability"],ascending=False).head(10)
# Out:
#      Rank                                       Title  \
# 50     51  Star Wars: Episode VII - The Force Awakens
# 85     86                              Jurassic World
# 119   120                                Finding Dory
# 87     88                                      Avatar
# 76     77                                The Avengers
# 15     16                     The Secret Life of Pets
# 688   689                                 Toy Story 3
# 12     13                                   Rogue One
# 174   175                                      Frozen
# 797   798                             Despicable Me 2
#
#                           Genre  \
# 50     Action,Adventure,Fantasy
# 85      Action,Adventure,Sci-Fi
# 119  Animation,Adventure,Comedy
# 87     Action,Adventure,Fantasy
# 76                Action,Sci-Fi
# 15   Animation,Adventure,Comedy
# 688  Animation,Adventure,Comedy
# 12      Action,Adventure,Sci-Fi
# 174  Animation,Adventure,Comedy
# 797  Animation,Adventure,Comedy
#
# ...

# %% [markdown]
# 17) Create a column that categorizes movies by rating:
# a) Rating < 6: Poor
# b) 6 ≤ Rating < 7.5: Average
# c) Rating ≥ 7.5: Excellent

# %%
conditions=[df['Rating'] < 6 ,(df['Rating']>=6) & (df['Rating']<=7.5) ,df['Rating'] >=7.5 ]
values =["poor",'average','excellent']
df['movie_rating']= np.select(conditions,values,default='UNKNOWN')
df.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %% [markdown]
# 18) Create a custom function to score movies based on:
# i) Apply row['Rating'] * 10 + row['Revenue (Millions)'] as High score
# Apply a function to dataset to assign the score

# %%
def calculate_high_score(row):

    return row['Rating'] * 10 + row['Revenue (Millions)']
df['High_Score'] = df.apply(calculate_high_score, axis=1)
print(df[['Title', 'Rating', 'Revenue (Millions)', 'High_Score']].head())
# Out:
#                      Title  Rating  Revenue (Millions)  High_Score
# 0  Guardians of the Galaxy     8.1              333.13      414.13
# 1               Prometheus     7.0              126.46      196.46
# 2                    Split     7.3              138.12      211.12
# 3                     Sing     7.2              270.32      342.32
# 4            Suicide Squad     6.2              325.02      387.02
